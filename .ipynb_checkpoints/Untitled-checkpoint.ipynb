# %%
import pandas as pd
import csv

data_list = list()
aggregated_layer_list = list()
f = open('./profiling_result/result_neat.csv','r',encoding="utf-8")
reader = csv.reader(f,delimiter=" ")
remove_set = ("")
for line in reader:
    line = [data for data in line if data not in ""]   
    if line == []:
        continue
    elif 'tvmgen' in line[0]:

        line[0] = line[0].split("_")[3:] #get rid of tvmgen_default_fused 
        
        if line[0][-1].isnumeric(): #get rid of number if ends with number
            line[0].pop()
             
        else:
            pass #if doesn't end with a number, leave it
        
        line[0] = "".join(line[0]) #make str again
        if line[0] not in aggregated_layer_list:
            aggregated_layer_list.append(line[0])
            
        data_list.append(line[:5])
    elif line[0] == 'Total':
        Total = line
    elif line[0] == 'Sum':
        Sum = line
    else:
        continue
print(aggregated_layer_list)
print(data_list)

layer_dict = dict()
for layer in aggregated_layer_list: 
      
    layer_dict["aggregated_duration_"+layer] = 0
    layer_dict["aggregated_percentage_"+layer] = 0
    layer_dict["aggregated_count_"+layer] = 0
    
layer_dict_keys = layer_dict.keys()

print(layer_dict_keys)


for data in data_list:
    # str -> int or float
    data[1] = round(float(data[1].replace(",","")),3)
    data[2] = round(float(data[2]),3)
    data[4] = int(data[4])
    
    layer_dict['aggregated_duration_'+ data[0]] += data[1]
    layer_dict['aggregated_percentage_'+ data[0]] += data[2]
    layer_dict['aggregated_count_'+ data[0]] += data[4]
        

print(Total)
print(Sum)
for key in layer_dict_keys:
    print(key)
    print(layer_dict[key])
# Out:
# ['nnconv2d', 'add', 'nndense', 'nnbiasadd', 'multiply', 'nnrelu', 'rsqrt', 'negative', 'nnmaxpool2d', 'nnglobalavgpool2d']
# [['nnconv2d', '126,905.31', '27.35', 'cpu0', '23'], ['nnconv2d', '73,482.25', '15.84', 'cpu0', '22'], ['nnconv2d', '71,574.46', '15.43', 'cpu0', '23'], ['nnconv2d', '23,117.66', '4.98', 'cpu0', '4'], ['nnconv2d', '22,224.23', '4.79', 'cpu0', '3'], ['nnconv2d', '17,636.44', '3.80', 'cpu0', '3'], ['nnconv2d', '11,484.50', '2.48', 'cpu0', '4'], ['nnconv2d', '10,485.76', '2.26', 'cpu0', '4'], ['nnconv2d', '9,530.42', '2.05', 'cpu0', '3'], ['nnconv2d', '9,154.44', '1.97', 'cpu0', '3'], ['nnconv2d', '6,788.77', '1.46', 'cpu0', '1'], ['nnconv2d', '6,583.73', '1.42', 'cpu0', '2'], ['nnconv2d', '6,522.94', '1.41', 'cpu0', '1'], ['nnconv2d', '6,295.83', '1.36', 'cpu0', '1'], ['nnconv2d', '6,212.93', '1.34', 'cpu0', '2'], ['nnconv2d', '5,851.98', '1.26', 'cpu0', '1'], ['nnconv2d', '1,767.87', '0.38', 'cpu0', '1'], ['nnconv2d', '1,718.34', '0.37', 'cpu0', '1'], ['nnconv2d', '1,648.46', '0.36', 'cpu0', '1'], ['add', '1,483.24', '0.32', 'cpu0', '23'], ['nndense', '1,267.32', '0.27', 'cpu0', '1'], ['add', '1,256.01', '0.27', 'cpu0', '3'], ['nnbiasadd', '1,234.23', '0.27', 'cpu0', '23'], ['multiply', '1,198.83', '0.26', 'cpu0', '100'], ['multiply', '1,110.09', '0.24', 'cpu0', '4'], ['multiply', '1,082.57', '0.23', 'cpu0', '24'], ['add', '1,027.28', '0.22', 'cpu0', '24'], ['nnrelu', '1,005.87', '0.22', 'cpu0', '23'], ['nnrelu', '942.64', '0.20', 'cpu0', '46'], ['multiply', '932.80', '0.20', 'cpu0', '46'], ['add', '907.80', '0.20', 'cpu0', '46'], ['add', '906.83', '0.20', 'cpu0', '4'], ['nnbiasadd', '888.06', '0.19', 'cpu0', '3'], ['nnconv2d', '770.52', '0.17', 'cpu0', '1'], ['nnrelu', '714.04', '0.15', 'cpu0', '3'], ['add', '666.94', '0.14', 'cpu0', '50'], ['rsqrt', '650.77', '0.14', 'cpu0', '50'], ['add', '579.56', '0.12', 'cpu0', '50'], ['multiply', '571.97', '0.12', 'cpu0', '48'], ['negative', '571.58', '0.12', 'cpu0', '50'], ['add', '532.62', '0.11', 'cpu0', '4'], ['nnbiasadd', '510.80', '0.11', 'cpu0', '23'], ['nnbiasadd', '477.68', '0.10', 'cpu0', '4'], ['multiply', '435.75', '0.09', 'cpu0', '5'], ['nnmaxpool2d', '375.06', '0.08', 'cpu0', '1'], ['multiply', '346.16', '0.07', 'cpu0', '1'], ['add', '334.13', '0.07', 'cpu0', '5'], ['add', '319.91', '0.07', 'cpu0', '24'], ['rsqrt', '298.11', '0.06', 'cpu0', '24'], ['add', '281.80', '0.06', 'cpu0', '1'], ['add', '278.17', '0.06', 'cpu0', '24'], ['negative', '267.30', '0.06', 'cpu0', '24'], ['nnrelu', '264.34', '0.06', 'cpu0', '4'], ['multiply', '255.15', '0.05', 'cpu0', '22'], ['nnrelu', '225.67', '0.05', 'cpu0', '1'], ['nnbiasadd', '216.97', '0.05', 'cpu0', '3'], ['multiply', '211.69', '0.05', 'cpu0', '6'], ['nnrelu', '190.27', '0.04', 'cpu0', '6'], ['add', '188.35', '0.04', 'cpu0', '6'], ['multiply', '186.67', '0.04', 'cpu0', '16'], ['nnrelu', '177.83', '0.04', 'cpu0', '8'], ['multiply', '171.43', '0.04', 'cpu0', '8'], ['multiply', '169.20', '0.04', 'cpu0', '14'], ['add', '165.64', '0.04', 'cpu0', '8'], ['add', '161.08', '0.03', 'cpu0', '11'], ['rsqrt', '146.66', '0.03', 'cpu0', '11'], ['negative', '130.82', '0.03', 'cpu0', '11'], ['nnbiasadd', '130.39', '0.03', 'cpu0', '4'], ['add', '125.05', '0.03', 'cpu0', '11'], ['multiply', '123.79', '0.03', 'cpu0', '4'], ['nnbiasadd', '116.15', '0.03', 'cpu0', '3'], ['add', '104.60', '0.02', 'cpu0', '8'], ['add', '103.74', '0.02', 'cpu0', '3'], ['rsqrt', '99.07', '0.02', 'cpu0', '8'], ['multiply', '98.92', '0.02', 'cpu0', '6'], ['add', '95.89', '0.02', 'cpu0', '7'], ['add', '95.09', '0.02', 'cpu0', '8'], ['nnrelu', '92.39', '0.02', 'cpu0', '6'], ['multiply', '91.93', '0.02', 'cpu0', '8'], ['negative', '90.92', '0.02', 'cpu0', '7'], ['negative', '88.80', '0.02', 'cpu0', '8'], ['add', '88.09', '0.02', 'cpu0', '6'], ['add', '87.87', '0.02', 'cpu0', '4'], ['rsqrt', '83.94', '0.02', 'cpu0', '7'], ['add', '75.36', '0.02', 'cpu0', '7'], ['add', '67.30', '0.01', 'cpu0', '4'], ['nnrelu', '63.94', '0.01', 'cpu0', '3'], ['rsqrt', '63.01', '0.01', 'cpu0', '4'], ['nnbiasadd', '62.54', '0.01', 'cpu0', '3'], ['nnglobalavgpool2d', '47.25', '0.01', 'cpu0', '1'], ['add ...
# dict_keys(['aggregated_duration_nnconv2d', 'aggregated_percentage_nnconv2d', 'aggregated_count_nnconv2d', 'aggregated_duration_add', 'aggregated_percentage_add', 'aggregated_count_add', 'aggregated_duration_nndense', 'aggregated_percentage_nndense', 'aggregated_count_nndense', 'aggregated_duration_nnbiasadd', 'aggregated_percentage_nnbiasadd', 'aggregated_count_nnbiasadd', 'aggregated_duration_multiply', 'aggregated_percentage_multiply', 'aggregated_count_multiply', 'aggregated_duration_nnrelu', 'aggregated_percentage_nnrelu', 'aggregated_count_nnrelu', 'aggregated_duration_rsqrt', 'aggregated_percentage_rsqrt', 'aggregated_count_rsqrt', 'aggregated_duration_negative', 'aggregated_percentage_negative', 'aggregated_count_negative', 'aggregated_duration_nnmaxpool2d', 'aggregated_percentage_nnmaxpool2d', 'aggregated_count_nnmaxpool2d', 'aggregated_duration_nnglobalavgpool2d', 'aggregated_percentage_nnglobalavgpool2d', 'aggregated_count_nnglobalavgpool2d'])
# ['Total', '463,991.14', 'cpu0', '1']
# ['Sum', '448,495.83', '96.66', '1,348']
# aggregated_duration_nnconv2d
# 419756.84
# aggregated_percentage_nnconv2d
# 90.48
# aggregated_count_nnconv2d
# 104
# aggregated_duration_add
# 9979.869999999999
# aggregated_percentage_add
# 2.14
# aggregated_count_add
# 346
# aggregated_duration_nndense
# 1267.32
# aggregated_percentage_nndense
# 0.27
# aggregated_count_nndense
# 1
# aggregated_duration_nnbiasadd
# 3636.8199999999997
# aggregated_percentage_nnbiasadd
# 0.7900000000000001
# aggregated_count_nnbiasadd
# 66
# aggregated_duration_multiply
# 6986.95
# aggregated_percentage_multiply
# 1.5000000000000002
# aggregated_count_multiply
# 312
# aggregated_duration_nnrelu
# 3676.9900000000002
# aggregated_percentage_nnrelu
# 0.7900000000000003
# aggregated_count_nnrelu
# 100
# aggregated_duration_rsqrt
# 1341.56
# aggregated_percentage_rsqrt
# 0.28
# aggregated_count_rsqrt
# 104
# aggregated_duration_negative
# 1194.6000000000001
# aggregated_percentage_negative
# 0.25999999999999995
# aggregated_count_negative
# 104
# aggregated_duration_nnmaxpool2d
# 375.06
# aggregated_percentage_nnmaxpool2d
# 0.08
# aggregated_count_nnmaxpool2d
# 1
# aggregated_duration_nnglobalavgpool2d
# 47.25
# aggregated_percentage_nnglobalavgpool2d
# 0.01
# aggregated_count_nnglobalavgpool2d
# 1

# %%
name = data['Name']
duration = data['Duration (us)']
print(name)
print(duration)

def to_int(duration):
    duration = duration.replace(",","")
    duration = int(duration)
    return duration
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/56/fmw8pgl15ybc1d1q0yg0yj4c0000gn/T/ipykernel_35029/2148465062.py in <module>
# ----> 1 name = data['Name']
#       2 duration = data['Duration (us)']
#       3 print(name)
#       4 print(duration)
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Name'
